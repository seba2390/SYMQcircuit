# %%
import numpy as np

from ma_QAOA.ma_qaoa_src.Ansatz import *
import scipy as sc
from qiskit.visualization import plot_histogram

# %%
# Generating random graph 
n = 3
rng_seed = int(np.random.randint(0,2**31-1))
np.random.seed(rng_seed)
G = nx.Graph()
G.add_nodes_from(np.arange(0, n, 1))
edge_list = generate_random_graph(nodes=n,weighted=True,w_min=1e-2,seed=rng_seed)

# tuple is (i,j,weight) where (i,j) is the edge
G.add_weighted_edges_from(edge_list)

# %%
# Calculating optimal partition and plotting
best_cost, best_perm = qubo_min_cost_partition(nr_nodes=n,Q_mat=get_qubo(size=n,edges=edge_list))
colors = ["r" if best_perm[i] == 0 else "c" for i in range(n)]
print("\nBest solution = " + str(best_perm) + " cost = " + str(best_cost))
pos = nx.spring_layout(G)
draw_graph(G, colors, pos)
# Out:
# Best solution = [1 1 0] cost = -1.0359000000000003

# %%
# Number of repetitions of (cost, mixer) in circuit
layers=4

# Defining instance of QAOA ansatz
QAOA_objective = MAQAOAansatz(n_qubits=n, n_layers=layers, w_edges=edge_list, backend="SYMQ", precision=64)

# Initial guess for parameters (beta, gamma) of circuit
np.random.seed(0)
theta_min, theta_max = -np.pi, np.pi
gamma_i = np.random.uniform(low=theta_min, high=theta_max,size=QAOA_objective.nr_cost_terms * layers).tolist()
beta_i = np.random.uniform(low=theta_min, high=theta_max,size=QAOA_objective.nr_mixer_terms * layers).tolist()
theta_i = gamma_i + beta_i

Nfeval=1
verbose = True
def printx(xk, convergence=0.0):
    global Nfeval
    if verbose:
        print(' --- Iteration nr.: {0:4d}'.format(Nfeval) + ' --- \n')
        Nfeval += 1


# ------ Optimizer run ------ #

# Optimizer technique 1)
_available_methods_ = ['Nelder-Mead', 'Powell', 'COBYLA', 'trust-constr']
res = sc.optimize.minimize(fun=QAOA_objective.evaluate_circuit, x0=theta_i,method=_available_methods_[2],callback=printx, options={'disp': True, 'maxiter': 500})

# Optimizer technique 2)
#res = sc.optimize.basinhopping(func=QAOA_objective.evaluate_circuit, x0=theta_i, niter=10, stepsize=0.75)

# Optimizer technique 3)
#_available_strategies_ = ['best1bin', 'best1exp', 'rand1exp', 'randtobest1exp', 'currenttobest1exp', 'best2exp', 'rand2exp', 'randtobest1bin', 'currenttobest1bin', 'best2bin', 'rand2bin', 'rand1bin']
#res = sc.optimize.differential_evolution(func=QAOA_objective.evaluate_circuit,bounds=[(theta_min, theta_max) for angle in theta_i], strategy=_available_strategies_[1],popsize=2, maxiter=50)

# Optimizer technique 4)
#_available_sampling_methods_ = ['simplicial', 'halton', 'sobol']
#res = sc.optimize.shgo(func=QAOA_objective.evaluate_circuit, bounds=[(theta_min, theta_max) for angle in theta_i], sampling_method=_available_sampling_methods_[2],callback=printx)

# Optimizer technique 5)
#res = sc.optimize.dual_annealing(func=QAOA_objective.evaluate_circuit, bounds=[(theta_min, theta_max) for angle in theta_i], maxfun=1000)

# Optimizer technique 6)
#res = sc.optimize.direct(func=QAOA_objective.evaluate_circuit, bounds=[(theta_min, theta_max) for angle in theta_i], maxfun=400)

# Final parameters (beta, gamma) for circuit
theta_f = res.x.tolist()
res
# Out:
#  --- Iteration nr.:    1 ---
#
#  --- Iteration nr.:    2 ---
#
#  --- Iteration nr.:    3 ---
#
#  --- Iteration nr.:    4 ---
#
#  --- Iteration nr.:    5 ---
#
#  --- Iteration nr.:    6 ---
#
#  --- Iteration nr.:    7 ---
#
#  --- Iteration nr.:    8 ---
#
#  --- Iteration nr.:    9 ---
#
#  --- Iteration nr.:   10 ---
#
#  --- Iteration nr.:   11 ---
#
#  --- Iteration nr.:   12 ---
#
#  --- Iteration nr.:   13 ---
#  --- Iteration nr.:   14 ---
#
#  --- Iteration nr.:   15 ---
#
#  --- Iteration nr.:   16 ---
#
#  --- Iteration nr.:   17 ---
#
#  --- Iteration nr.:   18 ---
#
#  --- Iteration nr.:   19 ---
#
#  --- Iteration nr.:   20 ---
#
#  --- Iteration nr.:   21 ---
#
#  --- Iteration nr.:   22 ---
#
#  --- Iteration nr.:   23 ---
#
#  --- Iteration nr.:   24 ---
#
#  --- Iteration nr.:   25 ---
#
#  --- Iteration nr.:   26 ---
#
#  --- Iteration nr.:   27 ---
#
#  --- Iteration nr.:   28 ---
#
#  --- Iteration nr.:   29 ---
#
#  --- Iteration nr.:   30 ---
#  --- Iteration nr.:   31 ---
#
#  --- Iteration nr.:   32 ---
#
#  --- Iteration nr.:   33 ---
#
#  --- Iteration nr.:   34 ---
#
#  --- Iteration nr.:   35 ---
#
#  --- Iteration nr.:   36 ---
#
#  --- Iteration nr.:   37 ---
#
#  --- Iteration nr.:   38 ---
#
#  --- Iteration nr.:   39 ---
#
#  --- Iteration nr.:   40 ---
#
#  --- Iteration nr.:   41 ---
#
#  --- Iteration nr.:   42 ---
#
#  --- Iteration nr.:   43 ---
#
#  --- Iteration nr.:   44 ---
#
#  --- Iteration nr.:   45 ---
#
#  --- Iteration nr.:   46 ---
#
#  --- Iteration nr.:   47 ---
#
#  --- Iteration nr.:   48 ---
#
#  --- Iteration nr.:   49 ---
#
#  --- Iteration nr.:   50 ---
#
#  --- Iteration nr.:   51 ---
#
#  --- Iteration nr.:   52 ---
#
#  --- Iteration nr.:   53 ---
#
#  --- Iteration nr.:   54 ---
#
#  --- Iteration nr.:   55 ---
#
#  --- Iteration nr.:   56 ---
#
#  --- Iteration nr.:   57 ---
#
#  --- Iteration nr.:   58 ---
#
#  --- Iteration nr.:   59 ---
#
#  --- Iteration nr.:   60 ---
#
#  --- Iteration nr.:   61 ---
#
#  --- Iteration nr.:   62 ---
#
#  --- Iteration nr.:   63 ---
#
#  --- Iteration nr.:   64 ---
#
#  --- Iteration nr.:   65 ---
#
#  --- Iteration nr.:   66 ---
#
#  --- Iteration nr.:   67 ---
#
#  --- Iteration nr.:   68 ---
#
#  --- Iteration nr.:   69 ---
#
#  --- Iteration nr.:   70 ---
#
#  --- Iteration nr.:   71 ---
#
#  --- Iteration nr.:   72 ---
#
#  --- Iteration nr.:   73 ---
#
#  --- Iteration nr.:   74 ---
#
#  --- Iteration nr.:   75 ---
#
#  --- Iteration nr.:   76 ---
#
#  --- Iteration nr.:   77 ---
#
#  --- Iteration nr.:   78 ---
#
#  --- Iteration nr.:   79 ---
#
#  --- Iteration nr.:   80 ---
#
#  --- Iteration nr.:   81 ---
#
#  --- Iteration nr.:   82 ---
#
#  --- Iteration nr.:   83 ---
#
#  --- Iteration nr.:   84 ---
#
#  --- Iteration nr.:   85 ---
#  --- Iteration nr.:   86 ---
#
#  --- Iteration nr.:   87 ---
#
#  --- Iteration nr.:   88 ---
#
#  --- Iteration nr.:   89 ---
#
#  --- Iteration nr.:   90 ---
#
#  --- Iteration nr.:   91 ---
#
#  --- Iteration nr.:   92 ---
#
#  --- Iteration nr.:   93 ---
#
#  --- Iteration nr.:   94 ---
#
#  --- Iteration nr.:   95 ---
#
#  --- Iteration nr.:   96 ---
#
#  --- Iteration nr.:   97 ---
#
#  --- Iteration nr.:   98 ---
#
#  --- Iteration nr.:   99 ---
#
#  --- Iteration nr.:  100 ---
#
#  --- Iteration nr.:  101 ---
#
#  --- Iteration nr.:  102 ---
#
#  --- Iteration nr.:  103 ---
#
#  --- Iteration nr.:  104 ---
#
#  --- Iteration nr.:  105 ---
#
#  --- Iteration nr.:  106 ---
#
#  --- Iteration nr.:  107 ---
#
#  --- Iteration nr.:  108 ---
#
#  --- Iteration nr.:  109 ---
#
#  --- Iteration nr.:  110 ---
#
#  --- Iteration nr.:  111 ---
#
#  --- Iteration nr.:  112 ---
#
#  --- Iteration nr.:  113 ---
#
#  --- Iteration nr.:  114 ---
#
#  --- Iteration nr.:  115 ---
#
#  --- Iteration nr.:  116 ---
#
#  --- Iteration nr.:  117 ---
#
#  --- Iteration nr.:  118 ---
#
#  --- Iteration nr.:  119 ---
#
#  --- Iteration nr.:  120 ---
#
#  --- Iteration nr.:  121 ---
#
#  --- Iteration nr.:  122 ---
#
#  --- Iteration nr.:  123 ---
#
#  --- Iteration nr.:  124 ---
#
#  --- Iteration nr.:  125 ---
#
#  --- Iteration nr.:  126 ---
#
#  --- Iteration nr.:  127 ---
#
#  --- Iteration nr.:  128 ---
#
#  --- Iteration nr.:  129 ---
#
#  --- Iteration nr.:  130 ---
#
#  --- Iteration nr.:  131 ---
#
#  --- Iteration nr.:  132 ---
#
#  --- Iteration nr.:  133 ---
#
#  --- Iteration nr.:  134 ---
#
#  --- Iteration nr.:  135 ---
#
#  --- Iteration nr.:  136 ---
#
#  --- Iteration nr.:  137 ---
#
#  --- Iteration nr.:  138 ---
#
#  --- Iteration nr.:  139 ---
#
#  --- Iteration nr.:  140 ---
#
#  --- Iteration nr.:  141 ---
#
#  --- Iteration nr.:  142 ---
#
#  --- Iteration nr.:  143 ---
#
#  --- Iteration nr.:  144 ---
#
#  --- Iteration nr.:  145 ---
#
#  --- Iteration nr.:  146 ---
#
#  --- Iteration nr.:  147 ---
#
#  --- Iteration nr.:  148 ---
#
#  --- Iteration nr.:  149 ---
#
#  --- Iteration nr.:  150 ---
#
#  --- Iteration nr.:  151 ---
#
#  --- Iteration nr.:  152 ---
#
#  --- Iteration nr.:  153 ---
#
#  --- Iteration nr.:  154 ---
#
#  --- Iteration nr.:  155 ---
#
#  --- Iteration nr.:  156 ---
#
#  --- Iteration nr.:  157 ---
#
#  --- Iteration nr.:  158 ---
#  --- Iteration nr.:  159 ---
#
#  --- Iteration nr.:  160 ---
#
#  --- Iteration nr.:  161 ---
#
#  --- Iteration nr.:  162 ---
#
#  --- Iteration nr.:  163 ---
#
#  --- Iteration nr.:  164 ---
#
#  --- Iteration nr.:  165 ---
#
#  --- Iteration nr.:  166 ---
#
#  --- Iteration nr.:  167 ---
#
#  --- Iteration nr.:  168 ---
#
#  --- Iteration nr.:  169 ---
#
#  --- Iteration nr.:  170 ---
#
#  --- Iteration nr.:  171 ---
#
#  --- Iteration nr.:  172 ---
#
#  --- Iteration nr.:  173 ---
#
#  --- Iteration nr.:  174 ---
#
#  --- Iteration nr.:  175 ---
#
#  --- Iteration nr.:  176 ---
#
#  --- Iteration nr.:  177 ---
#
#  --- Iteration nr.:  178 ---
#
#  --- Iteration nr.:  179 ---
#
#  --- Iteration nr.:  180 ---
#
#  --- Iteration nr.:  181 ---
#
#  --- Iteration nr.:  182 ---
#
#  --- Iteration nr.:  183 ---
#
#  --- Iteration nr.:  184 ---
#
#  --- Iteration nr.:  185 ---
#  --- Iteration nr.:  186 ---
#
#  --- Iteration nr.:  187 ---
#
#  --- Iteration nr.:  188 ---
#
#  --- Iteration nr.:  189 ---
#
#  --- Iteration nr.:  190 ---
#
#  --- Iteration nr.:  191 ---
#
#  --- Iteration nr.:  192 ---
#
#  --- Iteration nr.:  193 ---
#
#  --- Iteration nr.:  194 ---
#
#  --- Iteration nr.:  195 ---
#
#  --- Iteration nr.:  196 ---
#
#  --- Iteration nr.:  197 ---
#
#  --- Iteration nr.:  198 ---
#
#  --- Iteration nr.:  199 ---
#
#  --- Iteration nr.:  200 ---
#
#  --- Iteration nr.:  201 ---
#
#  --- Iteration nr.:  202 ---
#
#  --- Iteration nr.:  203 ---
#
#  --- Iteration nr.:  204 ---
#
#  --- Iteration nr.:  205 ---
#
#  --- Iteration nr.:  206 ---
#
#  --- Iteration nr.:  207 ---
#
#  --- Iteration nr.:  208 ---
#
#  --- Iteration nr.:  209 ---
#
#  --- Iteration nr.:  210 ---
#
#  --- Iteration nr.:  211 ---
#
#  --- Iteration nr.:  212 ---
#
#  --- Iteration nr.:  213 ---
#
#  --- Iteration nr.:  214 ---
#
#  --- Iteration nr.:  215 ---
#
#  --- Iteration nr.:  216 ---
#
#  --- Iteration nr.:  217 ---
#
#  --- Iteration nr.:  218 ---
#
#  --- Iteration nr.:  219 ---
#
#  --- Iteration nr.:  220 ---
#
#  --- Iteration nr.:  221 ---
#
#  --- Iteration nr.:  222 ---
#
#  --- Iteration nr.:  223 ---
#
#  --- Iteration nr.:  224 ---
#
#  --- Iteration nr.:  225 ---
#
#  --- Iteration nr.:  226 ---
#
#  --- Iteration nr.:  227 ---
#
#  --- Iteration nr.:  228 ---
#
#  --- Iteration nr.:  229 ---
#
#  --- Iteration nr.:  230 ---
#
#  --- Iteration nr.:  231 ---
#
#  --- Iteration nr.:  232 ---
#
#  --- Iteration nr.:  233 ---
#
#  --- Iteration nr.:  234 ---
#
#  --- Iteration nr.:  235 ---
#
#  --- Iteration nr.:  236 ---
#
#  --- Iteration nr.:  237 ---
#
#  --- Iteration nr.:  238 ---
#
#  --- Iteration nr.:  239 ---
#
#  --- Iteration nr.:  240 ---
#
#  --- Iteration nr.:  241 ---
#
#  --- Iteration nr.:  242 ---
#
#  --- Iteration nr.:  243 ---
#
#  --- Iteration nr.:  244 ---
#
#  --- Iteration nr.:  245 ---
#  --- Iteration nr.:  246 ---
#
#  --- Iteration nr.:  247 ---
#
#  --- Iteration nr.:  248 ---
#
#  --- Iteration nr.:  249 ---
#
#  --- Iteration nr.:  250 ---
#
#  --- Iteration nr.:  251 ---
#
#  --- Iteration nr.:  252 ---
#
#  --- Iteration nr.:  253 ---
#
#  --- Iteration nr.:  254 ---
#
#  --- Iteration nr.:  255 ---
#
#  --- Iteration nr.:  256 ---
#
#  --- Iteration nr.:  257 ---
#
#  --- Iteration nr.:  258 ---
#
#  --- Iteration nr.:  259 ---
#
#  --- Iteration nr.:  260 ---
#
#  --- Iteration nr.:  261 ---
#
#  --- Iteration nr.:  262 ---
#
#  --- Iteration nr.:  263 ---
#
#  --- Iteration nr.:  264 ---
#
#  --- Iteration nr.:  265 ---
#
#  --- Iteration nr.:  266 ---
#
#  --- Iteration nr.:  267 ---
#
#  --- Iteration nr.:  268 ---
#
#  --- Iteration nr.:  269 ---
#
#  --- Iteration nr.:  270 ---
#
#  --- Iteration nr.:  271 ---
#
#  --- Iteration nr.:  272 ---
#
#  --- Iteration nr.:  273 ---
#
#  --- Iteration nr.:  274 ---
#
#  --- Iteration nr.:  275 ---
#
#  --- Iteration nr.:  276 ---
#
#  --- Iteration nr.:  277 ---
#
#  --- Iteration nr.:  278 ---
#
#  --- Iteration nr.:  279 ---
#
#  --- Iteration nr.:  280 ---
#
#  --- Iteration nr.:  281 ---
#
#  --- Iteration nr.:  282 ---
#
#  --- Iteration nr.:  283 ---
#
#  --- Iteration nr.:  284 ---
#
#  --- Iteration nr.:  285 ---
#
#  --- Iteration nr.:  286 ---
#
#  --- Iteration nr.:  287 ---
#  --- Iteration nr.:  288 ---
#
#  --- Iteration nr.:  289 ---
#
#  --- Iteration nr.:  290 ---
#
#  --- Iteration nr.:  291 ---
#
#  --- Iteration nr.:  292 ---
#
#  --- Iteration nr.:  293 ---
#
#  --- Iteration nr.:  294 ---
#
#  --- Iteration nr.:  295 ---
#
#  --- Iteration nr.:  296 ---
#
#  --- Iteration nr.:  297 ---
#
#  --- Iteration nr.:  298 ---
#
#  --- Iteration nr.:  299 ---
#
#  --- Iteration nr.:  300 ---
#
#  --- Iteration nr.:  301 ---
#
#  --- Iteration nr.:  302 ---
#
#  --- Iteration nr.:  303 ---
#
#  --- Iteration nr.:  304 ---
#
#  --- Iteration nr.:  305 ---
#
#  --- Iteration nr.:  306 ---
#
#  --- Iteration nr.:  307 ---
#
#  --- Iteration nr.:  308 ---
#
#  --- Iteration nr.:  309 ---
#
#  --- Iteration nr.:  310 ---
#
#  --- Iteration nr.:  311 ---
#
#  --- Iteration nr.:  312 ---
#
#  --- Iteration nr.:  313 ---
#
#  --- Iteration nr.:  314 ---
#
#  --- Iteration nr.:  315 ---
#
#  --- Iteration nr.:  316 ---
#
#  --- Iteration nr.:  317 ---
#
#  --- Iteration nr.:  318 ---
#
#  --- Iteration nr.:  319 ---
#
#  --- Iteration nr.:  320 ---
#
#  --- Iteration nr.:  321 ---
#
#  --- Iteration nr.:  322 ---
#
#  --- Iteration nr.:  323 ---
#
#  --- Iteration nr.:  324 ---
#
#  --- Iteration nr.:  325 ---
#
#  --- Iteration nr.:  326 ---
#
#  --- Iteration nr.:  327 ---
#
#  --- Iteration nr.:  328 ---
#
#  --- Iteration nr.:  329 ---
#
#  --- Iteration nr.:  330 ---
#
#  --- Iteration nr.:  331 ---
#
#  --- Iteration nr.:  332 ---
#
#  --- Iteration nr.:  333 ---
#
#  --- Iteration nr.:  334 ---
#
#  --- Iteration nr.:  335 ---
#
#  --- Iteration nr.:  336 ---
#
#  --- Iteration nr.:  337 ---
#  --- Iteration nr.:  338 ---
#
#  --- Iteration nr.:  339 ---
#
#  --- Iteration nr.:  340 ---
#
#  --- Iteration nr.:  341 ---
#
#  --- Iteration nr.:  342 ---
#
#  --- Iteration nr.:  343 ---
#
#  --- Iteration nr.:  344 ---
#
#  --- Iteration nr.:  345 ---
#
#  --- Iteration nr.:  346 ---
#
#  --- Iteration nr.:  347 ---
#
#  --- Iteration nr.:  348 ---
#
#  --- Iteration nr.:  349 ---
#
#  --- Iteration nr.:  350 ---
#
#  --- Iteration nr.:  351 ---
#
#  --- Iteration nr.:  352 ---
#
#  --- Iteration nr.:  353 ---
#
#  --- Iteration nr.:  354 ---
#
#  --- Iteration nr.:  355 ---
#
#  --- Iteration nr.:  356 ---
#
#  --- Iteration nr.:  357 ---
#
#  --- Iteration nr.:  358 ---
#  --- Iteration nr.:  359 ---
#
#  --- Iteration nr.:  360 ---
#
#  --- Iteration nr.:  361 ---
#
#  --- Iteration nr.:  362 ---
#
#  --- Iteration nr.:  363 ---
#
#  --- Iteration nr.:  364 ---
#
#  --- Iteration nr.:  365 ---
#
#  --- Iteration nr.:  366 ---
#
#  --- Iteration nr.:  367 ---
#
#  --- Iteration nr.:  368 ---
#
#  --- Iteration nr.:  369 ---
#
#  --- Iteration nr.:  370 ---
#
#  --- Iteration nr.:  371 ---
#
#  --- Iteration nr.:  372 ---
#
#  --- Iteration nr.:  373 ---
#
#  --- Iteration nr.:  374 ---
#
#  --- Iteration nr.:  375 ---
#
#  --- Iteration nr.:  376 ---
#
#  --- Iteration nr.:  377 ---
#
#  --- Iteration nr.:  378 ---
#
#  --- Iteration nr.:  379 ---
#
#  --- Iteration nr.:  380 ---
#
#  --- Iteration nr.:  381 ---
#
#  --- Iteration nr.:  382 ---
#
#  --- Iteration nr.:  383 ---
#
#  --- Iteration nr.:  384 ---
#
#  --- Iteration nr.:  385 ---
#  --- Iteration nr.:  386 ---
#
#  --- Iteration nr.:  387 ---
#
#  --- Iteration nr.:  388 ---
#
#  --- Iteration nr.:  389 ---
#
#  --- Iteration nr.:  390 ---
#
#  --- Iteration nr.:  391 ---
#
#  --- Iteration nr.:  392 ---
#
#  --- Iteration nr.:  393 ---
#
#  --- Iteration nr.:  394 ---
#
#  --- Iteration nr.:  395 ---
#
#  --- Iteration nr.:  396 ---
#
#  --- Iteration nr.:  397 ---
#
#  --- Iteration nr.:  398 ---
#
#  --- Iteration nr.:  399 ---
#
#  --- Iteration nr.:  400 ---
#
#  --- Iteration nr.:  401 ---
#
#  --- Iteration nr.:  402 ---
#
#  --- Iteration nr.:  403 ---
#
#  --- Iteration nr.:  404 ---
#
#  --- Iteration nr.:  405 ---
#
#  --- Iteration nr.:  406 ---
#
#  --- Iteration nr.:  407 ---
#
#  --- Iteration nr.:  408 ---
#
#  --- Iteration nr.:  409 ---
#
#  --- Iteration nr.:  410 ---
#
#  --- Iteration nr.:  411 ---
#
#  --- Iteration nr.:  412 ---
#
#  --- Iteration nr.:  413 ---
#
#  --- Iteration nr.:  414 ---
#
#  --- Iteration nr.:  415 ---
#
#  --- Iteration nr.:  416 ---
#
#  --- Iteration nr.:  417 ---
#
#  --- Iteration nr.:  418 ---
#
#  --- Iteration nr.:  419 ---
#
#  --- Iteration nr.:  420 ---
#
#  --- Iteration nr.:  421 ---
#
#  --- Iteration nr.:  422 ---
#
#  --- Iteration nr.:  423 ---
#
#  --- Iteration nr.:  424 ---
#
#  --- Iteration nr.:  425 ---
#
#  --- Iteration nr.:  426 ---
#
#  --- Iteration nr.:  427 ---
#
#  --- Iteration nr.:  428 ---
#
#  --- Iteration nr.:  429 ---
#
#  --- Iteration nr.:  430 ---
#
#  --- Iteration nr.:  431 ---
#
#  --- Iteration nr.:  432 ---
#
#  --- Iteration nr.:  433 ---
#
#  --- Iteration nr.:  434 ---
#
#  --- Iteration nr.:  435 ---
#
#  --- Iteration nr.:  436 ---
#
#  --- Iteration nr.:  437 ---
#
#  --- Iteration nr.:  438 ---
#
#  --- Iteration nr.:  439 ---
#
#  --- Iteration nr.:  440 ---
#
#  --- Iteration nr.:  441 ---
#
#  --- Iteration nr.:  442 ---
#
#  --- Iteration nr.:  443 ---
#
#  --- Iteration nr.:  444 ---
#
#  --- Iteration nr.:  445 ---
#
#  --- Iteration nr.:  446 ---
#
#  --- Iteration nr.:  447 ---
#
#  --- Iteration nr.:  448 ---
#
#  --- Iteration nr.:  449 ---
#
#  --- Iteration nr.:  450 ---
#
#  --- Iteration nr.:  451 ---
#
#  --- Iteration nr.:  452 ---
#
#  --- Iteration nr.:  453 ---
#
#  --- Iteration nr.:  454 ---
#
#  --- Iteration nr.:  455 ---
#
#  --- Iteration nr.:  456 ---
#
#  --- Iteration nr.:  457 ---
#
#  --- Iteration nr.:  458 ---
#
#  --- Iteration nr.:  459 ---
#
#  --- Iteration nr.:  460 ---
#
#  --- Iteration nr.:  461 ---
#
#  --- Iteration nr.:  462 ---
#
#  --- Iteration nr.:  463 ---
#
#  --- Iteration nr.:  464 ---
#
#  --- Iteration nr.:  465 ---
#
#  --- Iteration nr.:  466 ---
#
#  --- Iteration nr.:  467 ---
#
#  --- Iteration nr.:  468 ---
#
#  --- Iteration nr.:  469 ---
#
#  --- Iteration nr.:  470 ---
#
#  --- Iteration nr.:  471 ---
#
#  --- Iteration nr.:  472 ---
#
#  --- Iteration nr.:  473 ---
#
#  --- Iteration nr.:  474 ---
#
#  --- Iteration nr.:  475 ---
#
#  --- Iteration nr.:  476 ---
#
#  --- Iteration nr.:  477 ---
#
#  --- Iteration nr.:  478 ---
#
#  --- Iteration nr.:  479 ---
#
#  --- Iteration nr.:  480 ---
#
#  --- Iteration nr.:  481 ---
#
#  --- Iteration nr.:  482 ---
#
#  --- Iteration nr.:  483 ---
#
#  --- Iteration nr.:  484 ---
#
#  --- Iteration nr.:  485 ---
#
#  --- Iteration nr.:  486 ---
#
#  --- Iteration nr.:  487 ---
#
#  --- Iteration nr.:  488 ---
#
#  --- Iteration nr.:  489 ---
#
#  --- Iteration nr.:  490 ---
#
#  --- Iteration nr.:  491 ---
#
#  --- Iteration nr.:  492 ---
#
#  --- Iteration nr.:  493 ---
#
#  --- Iteration nr.:  494 ---
#
#  --- Iteration nr.:  495 ---
#
#  --- Iteration nr.:  496 ---
#
#  --- Iteration nr.:  497 ---
#
#  --- Iteration nr.:  498 ---
#
#  --- Iteration nr.:  499 ---
#
#  --- Iteration nr.:  500 ---
#
#  --- Iteration nr.:  501 ---
#
#
#    Return from subroutine COBYLA because the MAXFUN limit has been reached.
#
#    NFVALS =  500   F =-1.035897E+00    MAXCV = 0.000000E+00
#    X =-5.823361E-01   6.839934E-01   9.317156E-01   5.157939E-01  -2.516005E-01
#        6.272635E-01  -3.555652E-01   3.457138E+00   2.023430E+00   5.034800E-02
#        1.916123E+00   4.247915E-01  -2.945108E-01   2.786569E+00  -1.356456E+00
#       -2.712027E+00  -3.206906E+00   1.961876E+00   1.836673E+00   2.057148E+00
#        3.971460E+00   2.319669E+00  -7.938709E-02   1.493084E+00  -1.207118E+00
#        2.951108E-01  -2.112404E+00   2.881726E+00   2.465086E-01  -1.015608E+00
#       -1.641124E+00   1.868582E+00  -1.272550E-02   3.525345E-01  -2.821221E+00
#        6.156605E-01
#      fun: -1.03589711475415
#    maxcv: 0.0
#  message: 'Maximum number of function evaluations has been exceeded.'
#     nfev: 500
#   status: 2
#  success: False
#        x: array([-0.5823361 ,  0.68399339,  0.93171561,  0.51579391, -0.25160048,
#         0.62726351, -0.35556522,  3.45713825,  2.02342982,  0.050348  ,
#         1.91612264,  0.4247915 , -0.29451077,  2.78656904, -1.35645575,
#        -2.71202656, -3.20690626,  1.96187627,  1.83667261,  2.05714774,
#         3.97146025,  2.31966934, -0.07938709,  1.49308358, -1.20711751,
#         0.29511081, -2.11240378,  2.8817262 ,  0.24650861, -1.01560775,
#        -1.64112365,  1.86858221, -0.0127255 ,  0.3525345 , -2.82122109,
#         0.61566053])

# %%
plot_histogram(QAOA_objective.set_circuit(theta=theta_f).get_state_probabilities(reverse_states=True))
